# %% [markdown]
# ### Setting up

# %%
import backtrader as bt
import pandas as pd
import datetime
import backtrader.feeds as btfeeds
from IPython.core.interactiveshell import InteractiveShell 
import pyecharts.options as opts
from pyecharts.charts import Grid,Line,Page,Scatter,Page,Bar
from pyecharts.faker import Faker
InteractiveShell.ast_node_interactivity = "all"
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
from statsmodels.tsa.stattools import adfuller
import numpy as np
from collections import deque
from tabulate import tabulate
st_date = datetime.datetime(2022, 5, 23)
ed_date = datetime.datetime(2022, 6, 12)

# %%
if_codes = ['IF1910','IF1911','IF1912',
            'IF2001','IF2002','IF2003','IF2004','IF2005','IF2006',
            'IF2007','IF2008','IF2009','IF2010','IF2011','IF2012',
            'IF2101','IF2102','IF2103','IF2104','IF2105','IF2106',
            'IF2107','IF2108','IF2109','IF2110','IF2111','IF2112',
            'IF2201','IF2202','IF2203','IF2204','IF2205','IF2206']
ic_codes = ['IC1910','IC1911','IC1912',
            'IC2001','IC2002','IC2003','IC2004','IC2005','IC2006',
            'IC2007','IC2008','IC2009','IC2010','IC2011','IC2012',
            'IC2101','IC2102','IC2103','IC2104','IC2105','IC2106',
            'IC2107','IC2108','IC2109','IC2110','IC2111','IC2112',
            'IC2201','IC2202','IC2203','IC2204','IC2205','IC2206']
ih_codes = ['IH1910','IH1911','IH1912',
            'IH2001','IH2002','IH2003','IH2004','IH2005','IH2006',
            'IH2007','IH2008','IH2009','IH2010','IH2011','IH2012',
            'IH2101','IH2102','IH2103','IH2104','IH2105','IH2106',
            'IH2107','IH2108','IH2109','IH2110','IH2111','IH2112',
            'IH2201','IH2202','IH2203','IH2204','IH2205','IH2206']
cn_codes =  [
            'CN2111','CN2112','CN2201','CN2202',
            'CN2203','CN2204','CN2205','CN2206'
            ]
if_data = {}
ic_data = {}
ih_data = {}
cn_data = {}


for a in if_codes:
    if_data[a] =  pd.read_csv('Data/IF/'+a+'.csv', index_col = 0,skiprows = [0,2],parse_dates=True).dropna()
for a in ic_codes:
    ic_data[a] =  pd.read_csv('Data/IC/'+a+'.csv', index_col = 0,skiprows = [0,2],parse_dates=True).dropna()
for a in ih_codes:
    ih_data[a] =  pd.read_csv('Data/IH/'+a+'.csv', index_col = 0,skiprows = [0,2],parse_dates=True).dropna()
for a in cn_codes:
    cn_data[a] =  pd.read_csv('Data/CN/'+a+'.csv', index_col = 0,skiprows = [0,1,3],parse_dates=True).dropna()

csi300=pd.read_csv('Data\CSI300.csv', index_col = 0,skiprows = [0],parse_dates=True)
csi500= pd.read_csv('Data\CSI500.csv',index_col = 0,skiprows = [0],parse_dates=True)
sse50= pd.read_csv('Data\SSE50.csv',index_col = 0,skiprows = [0],parse_dates=True)
a50= pd.read_csv('Data\A50.csv',index_col = 0,skiprows = [0,1],parse_dates=True)

# %%
if_feeds = []
ic_feeds = []
cn_feeds = []
ih_feeds = []

if_rolldate = []
ic_rolldate = []
ih_rolldate = []

cn_rolldate = []

for k in if_data.keys():
    if if_data[k].index[-1] < pd.to_datetime(st_date):
        # print(if_data[k].index[-1])
        continue
    if_data[k].columns = ['Open','High','Low','Close','Volume','OpenInterest']
    if_data[k]['Volume'] = if_data[k]['Volume']*100000
    if_data[k] = if_data[k].between_time('13:00','11:29').between_time('9:30','14:59')
    if_data[k] = if_data[k].fillna(method= 'ffill').sort_index().drop_duplicates()

    if_feeds.append(bt.feeds.PandasData(dataname = if_data[k],name = k))
    if_rolldate.append(if_data[k].resample('1d').last().index[-2]+datetime.timedelta(hours=14,minutes=57))

for k in ic_data.keys():
    if ic_data[k].index[-1] < pd.to_datetime(st_date):
        # print(ic_data[k].index[-1])
        continue
    ic_data[k].columns = ['Open','High','Low','Close','Volume','OpenInterest']
    ic_data[k]['Volume'] = ic_data[k]['Volume']*100000
    ic_data[k] = ic_data[k].between_time('13:00','11:29').between_time('9:30','14:59')
    ic_data[k] = ic_data[k].fillna(method= 'ffill').sort_index().drop_duplicates()

    ic_feeds.append( bt.feeds.PandasData(dataname = ic_data[k],name = k))

for k in ih_data.keys():
    if ih_data[k].index[-1] < pd.to_datetime(st_date):
        # print(ih_data[k].index[-1])
        continue
    ih_data[k].columns = ['Open','High','Low','Close','Volume','OpenInterest']
    ih_data[k]['Volume'] = ih_data[k]['Volume']*100000
    ih_data[k] = ih_data[k].between_time('13:00','11:29').between_time('9:30','14:59')
    ih_data[k] = ih_data[k].fillna(method= 'ffill').sort_index().drop_duplicates()

    ih_feeds.append( bt.feeds.PandasData(dataname = ih_data[k],name = k))



csi300 = csi300.between_time('13:00','11:29').between_time('9:30','14:59').loc[st_date:].sort_index().drop_duplicates()
csi300.fillna(inplace = True,method = 'ffill')
csi500 = csi500.between_time('13:00','11:29').between_time('9:30','14:59').loc[st_date:].sort_index().drop_duplicates()
csi500.fillna(inplace = True,method = 'ffill')
sse50 = sse50.between_time('13:00','11:29').between_time('9:30','14:59').loc[st_date:].sort_index().drop_duplicates()
sse50.fillna(inplace = True,method = 'ffill')
a50 = a50.between_time('13:00','11:29').between_time('9:30','14:59').loc[st_date:].sort_index().drop_duplicates()
a50.fillna(inplace = True,method = 'ffill')

for k in cn_data.keys():    
    # cn_data[k]
    if cn_data[k].index[-1] < pd.to_datetime(st_date):
        # print(cn_data[k].index[-1])
        continue

    cn_data[k].columns = ['Open','High','Low','Close','Volume','OpenInterest']
    cn_data[k]['Volume'] = cn_data[k]['Volume']*100000
    cn_data[k] = cn_data[k].between_time('13:00','11:29').between_time('9:30','14:59')
    cn_data[k] = cn_data[k].fillna(method= 'ffill')
    cn_data[k] = cn_data[k].loc[cn_data[k].index&a50.index].dropna().sort_index().drop_duplicates()
    cn_feeds.append(bt.feeds.PandasData(dataname = cn_data[k],name = k))
    cn_rolldate.append(cn_data[k].resample('1d').last().index[-2]+datetime.timedelta(hours=14,minutes=57))

csi300_feed = bt.feeds.PandasData(dataname = csi300,fromdate=st_date,todate=ed_date,)
csi500_feed = bt.feeds.PandasData(dataname = csi500,fromdate=st_date,todate=ed_date,)
sse50_feed = bt.feeds.PandasData(dataname = sse50,fromdate=st_date,todate=ed_date,)

a50_feed = bt.feeds.PandasData(dataname = a50,fromdate=st_date,todate=ed_date,)
if_rolldate=if_rolldate[:-1]
# ic_rolldate = if_rolldate
cn_rolldate = cn_rolldate[:-1]

def cn_expire(dt,d):
    return dt in cn_rolldate

def if_expire(dt,d):
    if dt in if_rolldate :
        return True
    return False

# %%
class IFICStrategy(bt.Strategy):
    params = (

        ('margin', 25),  
        ('distor', 5),
        ('bias', 0),
        ('if_lot',3),
        ('ic_lot',1),
        ('cn_lot',27),
        ('logname','log.csv'),

    )

    def log(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.datetime()
        print('%s, %s' % (dt.isoformat(), txt))
    
    def write_record(self, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.datetime()
        self.portlog.write('%s, %.1f, %.1f, %.1f, %.1f, %.1f, %.1f,%d, %d, %d, %d, %d\n' 
                                        % ( dt.isoformat(),
                                            self.csi300_close[0],
                                            self.csi500_close[0],
                                            self.a50_close[0],
                                            self.if_close[0],
                                            self.ic_close[0],
                                            self.cn_close[0],
                                            self.getpositionbyname('IF').size,
                                            self.getpositionbyname('IC').size,
                                            self.getpositionbyname('CN').size,
                                            self.broker.get_cash(),
                                            self.broker.get_value()
                                       )
        )
    

    def notify_order(self, order):  
        if order.status in [order.Completed]:
            ops = None
            
            if order.isbuy():
                ops = 'Buy'
            elif order.issell():
                ops = 'Sell'
            if order.isbuy():
                self.log('BUY EXECUTED,%s,%.2f,%d,%.2f,%d,%d,%s,%.2f\n' % ( 
                                                        order.data._name,
                                                        
                                                        order.executed.price,
                                                        order.executed.size,
                                                        order.executed.pnl,
                                                        order.executed.psize,
                                                        order.executed.comm,
                                                        order.ref,
                                                        self.broker.get_value())
                                                    )

            else:  # Sell
                self.log('SELL EXECUTED,%s,%.2f,%d,%.2f,%d,%d,%s,%.2f\n' % ( 
                                                        order.data._name,
                                                       
                                                        order.executed.price,
                                                        order.executed.size,
                                                        order.executed.pnl,
                                                        order.executed.psize,
                                                        order.executed.comm,
                                                        order.ref,
                                                        self.broker.get_value())
                                                    )
            self.tradeLog.write('%s,%s,%s,%.2f,%d,%.2f,%d,%d,%d,%s,%.2f\n' % (
                                                        order.data._name,
                                                        bt.num2date(order.executed.dt),
                                                        ops,
                                                        order.executed.price,
                                                        order.executed.size,
                                                        order.executed.pnl,
                                                        self.base,
                                                        order.executed.psize,
                                                        order.executed.comm,
                                                        order.ref,
                                                        self.broker.get_value())
                                                    )
        self.order = None
        # Sentinel to None: new orders allowed
    def __init__(self):
        self.tradeLog = open('tradelog/'+self.p.logname, 'w+')
        self.tradeLog.write('Symbol,Datetime,Trade,Price,Size,PnL,Base,CurrentPos,Comm,ref,Value\n')
        self.portlog = open('portlog/'+self.p.logname, 'w+')
        self.portlog.write('Datetime,CSI300,CSI500,A50,IF,IC,CN,IF_pos,IC_pos,CN_pos,Cash,Value\n')
        self.order = None
        self.traded = False
        self.if_close = self.data0.close
        self.ic_close = self.data1.close
        self.cn_close = self.data2.close
        self.csi300_close = self.data3.close
        self.csi500_close = self.data4.close
        self.a50_close = self.data5.close
        self.cn_theo = None 
        self.theo_spread = None 
        self.lots_int = None
        self.base = 0
        
    def next(self):
        
        self.cn_theo = self.a50_close[0]*(self.p.if_lot*3*self.if_close[0] - self.p.ic_lot*2*self.ic_close[0])/(self.p.if_lot*3*self.csi300_close[0]-self.p.ic_lot*2*self.csi500_close[0])
        print(self.a50_close[0],self.csi300_close[0],self.csi500_close[0],self.if_close[0],self.ic_close[0])
        cn_bid = self.cn_theo - self.p.margin + self.base
        cn_ask = self.cn_theo + self.p.margin + self.base
        self.log("%.2f,%.2f,%.2f,%.2f,%.2f,%.d,%.d"%(self.if_close[0],self.ic_close[0],self.cn_close[0],cn_ask,cn_bid,self.base,self.broker.get_value()))
        self.write_record()
        if self.cn_close > cn_ask: # 市场价 大于 理论卖价，市场价过高， 按照市场价卖出CN
            size = (self.cn_close - cn_ask)//self.p.distor + 1 # size > 0
            self.buy( data = self.getdatabyname('IF'),
                      size = self.p.if_lot*size,
                      exectype=bt.Order.Market,coc=True)
            self.sell( data = self.getdatabyname('IC'),
                       size = self.p.ic_lot*size,
                       exectype=bt.Order.Market,coc=True)
            self.sell( data = self.getdatabyname('CN'),
                       size = self.p.cn_lot*size, # size < 0
                       exectype=bt.Order.Market,coc=True)
            self.base = self.base + size * self.p.distor # base 上移，抬高理论价
            
        if self.cn_close < cn_bid: # 市场价 小于 理论买价，市场价过低，按照市场价买入
            size = (cn_bid - self.cn_close)//self.p.distor + 1 # size > 0
            self.sell( data = self.getdatabyname('IF'),
                       size = self.p.if_lot*size,
                       exectype=bt.Order.Market,coc=True)
            self.buy( data = self.getdatabyname('IC'),
                      size = self.p.ic_lot*size,
                      exectype=bt.Order.Market,coc=True)
            self.buy( data = self.getdatabyname('CN'),
                      size = self.p.cn_lot*size, # size < 0
                      exectype=bt.Order.Market,coc=True)
            self.base = self.base - size * self.p.distor

        if self.data.datetime.datetime()+datetime.timedelta(minutes=1) in if_rolldate:
            print('ROLL')
            self.base = 0

            if self.getpositionbyname('IF').size != 0:
                self.order_target_size( data = self.getdatabyname('IF'),
                                        target= 0,
                                        exectype=bt.Order.Market,
                                        coc = True)
            if self.getpositionbyname('IC').size != 0:
                self.order_target_size( data = self.getdatabyname('IC'),
                                        target= 0,
                                        exectype=bt.Order.Market,
                                        coc = True)
            if self.getpositionbyname('CN').size != 0:
                self.order_target_size( data = self.getdatabyname('CN'),
                                        target= 0,
                                        exectype=bt.Order.Market,
                                        coc = True)
        if self.data.datetime.datetime()+datetime.timedelta(minutes=1) in cn_rolldate:
            print('ROLL')
            self.base = 0
            if self.getpositionbyname('IF').size != 0:
                self.order_target_size( data = self.getdatabyname('IF'),
                                        target= 0,
                                        exectype=bt.Order.Market,
                                        coc = True)
            if self.getpositionbyname('IC').size != 0:
                self.order_target_size( data = self.getdatabyname('IC'),
                                        target= 0,
                                        exectype=bt.Order.Market,
                                        coc = True)
            if self.getpositionbyname('CN').size != 0:
                self.order_target_size( data = self.getdatabyname('CN'),
                                        target= 0,
                                        exectype=bt.Order.Market,
                                        coc = True)

    def stop(self):
        self.tradeLog.close()
        self.portlog.close()

# %%
class IFICAbsDailyOpenStrategy(bt.Strategy):
    params = (

        ('margin', 25),  
        ('distor', 5),
        ('bias', 0),
        ('if_lot',3),
        ('ic_lot',1),
        ('cn_lot',30),
        ('logname','abs.csv'),

    )
    def start(self):
        header = [ 'len','Name','Code', 'Datetime', 'WeekDay', 'Open',
                  'High', 'Low', 'Close', 'Volume', 'OpenInterest']
        print(', '.join(header))

    def log(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.datetime()
        print('%s, %s' % (dt.isoformat(), txt))
    
    def write_record(self, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.datetime()
        self.portlog.write('%s, %.1f, %.1f, %.1f, %.1f, %.1f, %.1f,%d, %d, %d, %d, %d\n' 
                                        % ( dt.isoformat(),
                                            self.csi300_close,
                                            self.csi500_close,
                                            self.a50_close,
                                            self.if_close[0],
                                            self.ic_close[0],
                                            self.cn_close[0],
                                            self.getpositionbyname('IF').size,
                                            self.getpositionbyname('IC').size,
                                            self.getpositionbyname('CN').size,
                                            self.broker.get_cash(),
                                            self.broker.get_value()
                                       )
        )
    def notify_order(self, order):  
        if order.status in [order.Completed]:
            ops = None
            
            if order.isbuy():
                ops = 'Buy'
            elif order.issell():
                ops = 'Sell'
            if order.isbuy():
                self.log('BUY EXECUTED,%s,%s,%.2f,%d,%.2f,%d,%d,%s,%.2f\n' % ( 
                                                        order.data._name,
                                                        bt.num2date(order.executed.dt),
                                                        order.executed.price,
                                                        order.executed.size,
                                                        order.executed.pnl,
                                                        order.executed.psize,
                                                        order.executed.comm,
                                                        order.ref,
                                                        self.broker.get_value())
                                                    )

            else:  # Sell
                self.log('SELL EXECUTED,%s,%s,%.2f,%d,%.2f,%d,%d,%s,%.2f\n' % ( 
                                                        order.data._name,
                                                        bt.num2date(order.executed.dt),
                                                        order.executed.price,
                                                        order.executed.size,
                                                        order.executed.pnl,
                                                        order.executed.psize,
                                                        order.executed.comm,
                                                        order.ref,
                                                        self.broker.get_value())
                                                    )
            self.tradeLog.write('%s,%s,%s,%.2f,%d,%.2f,%d,%d,%d,%s,%.2f\n' % (
                                                        order.data._name,
                                                        bt.num2date(order.executed.dt),
                                                        ops,
                                                        order.executed.price,
                                                        order.executed.size,
                                                        order.executed.pnl,
                                                        self.base,
                                                        order.executed.psize,
                                                        order.executed.comm,
                                                        order.ref,
                                                        self.broker.get_value())
                                                    )
        self.order = None
        # Sentinel to None: new orders allowed
    def __init__(self):
        self.tradeLog = open('tradelog/'+self.p.logname, 'w+')
        self.tradeLog.write('Symbol,Dates,Trade,Price,Size,PnL,Base,CurrentPos,Comm,ref,Value\n')
        self.portlog = open('portlog/'+self.p.logname, 'w+')
        self.portlog.write('Datetime,CSI300,CSI500,A50,IF,IC,CN,IF_pos,IC_pos,CN_pos,Cash,Value\n')
        self.order = None
        self.traded = False
        self.if_close = self.data0.close
        self.ic_close = self.data1.close
        self.cn_close = self.data2.close
        self.csi300_close = None
        self.csi500_close = None
        self.a50_close = None
        self.cn_theo = None 
        self.theo_spread = None 
        self.lots_int = None
        self.base = 0
        self.week = 0

    def next(self):
        if self.csi300_close is None or self.csi500_close is None or self.a50_close is None:
            # if self.datetime.time() == datetime.time(hour = 9, minute=30):
            self.csi300_close = self.data3.close[0]
            self.csi500_close = self.data4.close[0]
            self.a50_close = self.data5.close[0]
            # self.log("%.2f,%.2f,%.2f,%.2f,%.2f,%.d,%.d"%(self.if_close[0],self.ic_close[0],self.cn_close[0],cn_ask,cn_bid,self.base,self.broker.get_value()))
            self.write_record()
        else:
            # print(self.datetime.date().weekday())
            
            if self.datetime.time() == datetime.time(hour = 9, minute=30): #and self.datetime.date().isocalendar()[1] >= self.week+4:
                self.week = self.datetime.date().isocalendar()[1]
                self.csi300_close = self.data3.close[0]
                self.csi500_close = self.data4.close[0]
                self.a50_close = self.data5.close[0]
            self.cn_theo = self.a50_close*(self.p.if_lot*3*self.if_close[0] - self.p.ic_lot*2*self.ic_close[0])/(self.p.if_lot*3*self.csi300_close-self.p.ic_lot*2*self.csi500_close)
            cn_bid = self.cn_theo - self.p.margin + self.base
            cn_ask = self.cn_theo + self.p.margin + self.base
            self.log("%.2f,%.2f,%.2f,%.2f,%.2f,%.d,%.d"%(self.if_close[0],self.ic_close[0],self.cn_close[0],cn_ask,cn_bid,self.base,self.broker.get_value()))
            self.write_record()

            if self.cn_close > cn_ask: # 市场价 大于 理论卖价，市场价过高， 按照市场价卖出CN
                size = (self.cn_close - cn_ask)//self.p.distor + 1 # size > 0
                self.buy( data = self.getdatabyname('IF'),
                        size = self.p.if_lot*size,
                        exectype=bt.Order.Market,coc=True)
                self.sell( data = self.getdatabyname('IC'),
                        size = self.p.ic_lot*size,
                        exectype=bt.Order.Market,coc=True)
                self.sell( data = self.getdatabyname('CN'),
                        size = self.p.cn_lot*size, # size < 0
                        exectype=bt.Order.Market,coc=True)
                self.base = self.base + size * self.p.distor # base 上移，抬高理论价
                
            if self.cn_close < cn_bid: # 市场价 小于 理论买价，市场价过低，按照市场价买入
                size = (cn_bid - self.cn_close)//self.p.distor + 1 # size > 0
                self.sell( data = self.getdatabyname('IF'),
                        size = self.p.if_lot*size,
                        exectype=bt.Order.Market,coc=True)
                self.buy( data = self.getdatabyname('IC'),
                        size = self.p.ic_lot*size,
                        exectype=bt.Order.Market,coc=True)
                self.buy( data = self.getdatabyname('CN'),
                        size = self.p.cn_lot*size, # size < 0
                        exectype=bt.Order.Market,coc=True)
                self.base = self.base - size * self.p.distor

            if self.data.datetime.datetime()+datetime.timedelta(minutes=1) in if_rolldate:
                self.base = 0

                if self.getpositionbyname('IF').size != 0:
                    self.order_target_size( data = self.getdatabyname('IF'),
                                            target= 0,
                                            exectype=bt.Order.Market,
                                            coc = True)
                if self.getpositionbyname('IC').size != 0:
                    self.order_target_size( data = self.getdatabyname('IC'),
                                            target= 0,
                                            exectype=bt.Order.Market,
                                            coc = True)
                if self.getpositionbyname('CN').size != 0:
                    self.order_target_size( data = self.getdatabyname('CN'),
                                            target= 0,
                                            exectype=bt.Order.Market,
                                            coc = True)
            if self.data.datetime.datetime()+datetime.timedelta(minutes=1) in cn_rolldate:
                self.base = 0
                if self.getpositionbyname('IF').size != 0:
                    self.order_target_size( data = self.getdatabyname('IF'),
                                            target= 0,
                                            exectype=bt.Order.Market,
                                            coc = True)
                if self.getpositionbyname('IC').size != 0:
                    self.order_target_size( data = self.getdatabyname('IC'),
                                            target= 0,
                                            exectype=bt.Order.Market,
                                            coc = True)
                if self.getpositionbyname('CN').size != 0:
                    self.order_target_size( data = self.getdatabyname('CN'),
                                            target= 0,
                                            exectype=bt.Order.Market,
                                            coc = True)


    def stop(self):
        self.tradeLog.close()
        self.portlog.close()

# %%
class IFICAbsDailyCloseStrategy(bt.Strategy):
    params = (

        ('margin', 25),  
        ('distor', 5),
        ('bias', 0),
        ('if_lot',3),
        ('ic_lot',1),
        ('cn_lot',30),
        ('logname','abs.csv'),

    )
    def start(self):
        header = [ 'len','Name','Code', 'Datetime', 'WeekDay', 'Open',
                  'High', 'Low', 'Close', 'Volume', 'OpenInterest']
        print(', '.join(header))

    def log(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.datetime()
        print('%s, %s' % (dt.isoformat(), txt))
    
    def write_record(self, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.datetime()
        self.portlog.write('%s, %.1f, %.1f, %.1f, %.1f, %.1f, %.1f,%d, %d, %d, %d, %d\n' 
                                        % ( dt.isoformat(),
                                            self.csi300_close,
                                            self.csi500_close,
                                            self.a50_close,
                                            self.if_close[0],
                                            self.ic_close[0],
                                            self.cn_close[0],
                                            self.getpositionbyname('IF').size,
                                            self.getpositionbyname('IC').size,
                                            self.getpositionbyname('CN').size,
                                            self.broker.get_cash(),
                                            self.broker.get_value()
                                       )
        )
    def notify_order(self, order):  
        if order.status in [order.Completed]:
            ops = None
            
            if order.isbuy():
                ops = 'Buy'
            elif order.issell():
                ops = 'Sell'
            if order.isbuy():
                self.log('BUY EXECUTED,%s,%s,%.2f,%d,%.2f,%d,%d,%s,%.2f\n' % ( 
                                                        order.data._name,
                                                        bt.num2date(order.executed.dt),
                                                        order.executed.price,
                                                        order.executed.size,
                                                        order.executed.pnl,
                                                        order.executed.psize,
                                                        order.executed.comm,
                                                        order.ref,
                                                        self.broker.get_value())
                                                    )

            else:  # Sell
                self.log('SELL EXECUTED,%s,%s,%.2f,%d,%.2f,%d,%d,%s,%.2f\n' % ( 
                                                        order.data._name,
                                                        bt.num2date(order.executed.dt),
                                                        order.executed.price,
                                                        order.executed.size,
                                                        order.executed.pnl,
                                                        order.executed.psize,
                                                        order.executed.comm,
                                                        order.ref,
                                                        self.broker.get_value())
                                                    )
            self.tradeLog.write('%s,%s,%s,%.2f,%d,%.2f,%d,%d,%d,%s,%.2f\n' % (
                                                        order.data._name,
                                                        bt.num2date(order.executed.dt),
                                                        ops,
                                                        order.executed.price,
                                                        order.executed.size,
                                                        order.executed.pnl,
                                                        self.base,
                                                        order.executed.psize,
                                                        order.executed.comm,
                                                        order.ref,
                                                        self.broker.get_value())
                                                    )
        self.order = None
        # Sentinel to None: new orders allowed
    def __init__(self):
        self.tradeLog = open('tradelog/'+self.p.logname, 'w+')
        self.tradeLog.write('Symbol,Dates,Trade,Price,Size,PnL,Base,CurrentPos,Comm,ref,Value\n')
        self.portlog = open('portlog/'+self.p.logname, 'w+')
        self.portlog.write('Datetime,CSI300,CSI500,A50,IF,IC,CN,IF_pos,IC_pos,CN_pos,Cash,Value\n')
        self.order = None
        self.traded = False
        self.if_close = self.data0.close
        self.ic_close = self.data1.close
        self.cn_close = self.data2.close
        self.csi300_close = None
        self.csi500_close = None
        self.a50_close = None
        self.cn_theo = None 
        self.theo_spread = None 
        self.lots_int = None
        self.base = 0
        self.week = 0

    def next(self):
        if self.csi300_close is None or self.csi500_close is None or self.a50_close is None:
            # if self.datetime.time() == datetime.time(hour = 9, minute=30):
            self.csi300_close = self.data3.close[0]
            self.csi500_close = self.data4.close[0]
            self.a50_close = self.data5.close[0]
            # self.log("%.2f,%.2f,%.2f,%.2f,%.2f,%.d,%.d"%(self.if_close[0],self.ic_close[0],self.cn_close[0],cn_ask,cn_bid,self.base,self.broker.get_value()))
            self.write_record()
        else:
            # print(self.datetime.date().weekday())
            
            if self.datetime.time() == datetime.time(hour = 14, minute=59): #and self.datetime.date().isocalendar()[1] >= self.week+4:
                print('REbasing!')
                self.week = self.datetime.date().isocalendar()[1]
                self.csi300_close = self.data3.close[0]
                self.csi500_close = self.data4.close[0]
                self.a50_close = self.data5.close[0]
            self.cn_theo = self.a50_close*(self.p.if_lot*3*self.if_close[0] - self.p.ic_lot*2*self.ic_close[0])/(self.p.if_lot*3*self.csi300_close-self.p.ic_lot*2*self.csi500_close)
            cn_bid = self.cn_theo - self.p.margin + self.base
            cn_ask = self.cn_theo + self.p.margin + self.base
            self.log("%.2f,%.2f,%.2f,%.2f,%.2f,%.d,%.d"%(self.if_close[0],self.ic_close[0],self.cn_close[0],cn_ask,cn_bid,self.base,self.broker.get_value()))
            self.write_record()

            if self.cn_close > cn_ask: # 市场价 大于 理论卖价，市场价过高， 按照市场价卖出CN
                size = (self.cn_close - cn_ask)//self.p.distor + 1 # size > 0
                self.buy( data = self.getdatabyname('IF'),
                        size = self.p.if_lot*size,
                        exectype=bt.Order.Market,coc=True)
                self.sell( data = self.getdatabyname('IC'),
                        size = self.p.ic_lot*size,
                        exectype=bt.Order.Market,coc=True)
                self.sell( data = self.getdatabyname('CN'),
                        size = self.p.cn_lot*size, # size < 0
                        exectype=bt.Order.Market,coc=True)
                self.base = self.base + size * self.p.distor # base 上移，抬高理论价
                
            if self.cn_close < cn_bid: # 市场价 小于 理论买价，市场价过低，按照市场价买入
                size = (cn_bid - self.cn_close)//self.p.distor + 1 # size > 0
                self.sell( data = self.getdatabyname('IF'),
                        size = self.p.if_lot*size,
                        exectype=bt.Order.Market,coc=True)
                self.buy( data = self.getdatabyname('IC'),
                        size = self.p.ic_lot*size,
                        exectype=bt.Order.Market,coc=True)
                self.buy( data = self.getdatabyname('CN'),
                        size = self.p.cn_lot*size, # size < 0
                        exectype=bt.Order.Market,coc=True)
                self.base = self.base - size * self.p.distor

            if self.data.datetime.datetime()+datetime.timedelta(minutes=1) in if_rolldate:
                self.base = 0

                if self.getpositionbyname('IF').size != 0:
                    self.order_target_size( data = self.getdatabyname('IF'),
                                            target= 0,
                                            exectype=bt.Order.Market,
                                            coc = True)
                if self.getpositionbyname('IC').size != 0:
                    self.order_target_size( data = self.getdatabyname('IC'),
                                            target= 0,
                                            exectype=bt.Order.Market,
                                            coc = True)
                if self.getpositionbyname('CN').size != 0:
                    self.order_target_size( data = self.getdatabyname('CN'),
                                            target= 0,
                                            exectype=bt.Order.Market,
                                            coc = True)
            if self.data.datetime.datetime()+datetime.timedelta(minutes=1) in cn_rolldate:
                self.base = 0
                if self.getpositionbyname('IF').size != 0:
                    self.order_target_size( data = self.getdatabyname('IF'),
                                            target= 0,
                                            exectype=bt.Order.Market,
                                            coc = True)
                if self.getpositionbyname('IC').size != 0:
                    self.order_target_size( data = self.getdatabyname('IC'),
                                            target= 0,
                                            exectype=bt.Order.Market,
                                            coc = True)
                if self.getpositionbyname('CN').size != 0:
                    self.order_target_size( data = self.getdatabyname('CN'),
                                            target= 0,
                                            exectype=bt.Order.Market,
                                            coc = True)


    def stop(self):
        self.tradeLog.close()
        self.portlog.close()

# %%
class IFICAbsRollStrategy(bt.Strategy):
    params = (

        ('margin', 25),  
        ('distor', 5),
        ('bias', 0),
        ('if_lot',3),
        ('ic_lot',1),
        ('cn_lot',30),
        ('logname','abs.csv'),

    )
    def start(self):
        header = [ 'len','Name','Code', 'Datetime', 'WeekDay', 'Open',
                  'High', 'Low', 'Close', 'Volume', 'OpenInterest']
        print(', '.join(header))

    def log(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.datetime()
        print('%s, %s' % (dt.isoformat(), txt))
    
    def write_record(self, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.datetime()
        self.portlog.write('%s, %.1f, %.1f, %.1f, %.1f, %.1f, %.1f,%d, %d, %d, %d, %d\n' 
                                        % ( dt.isoformat(),
                                            self.csi300_close,
                                            self.csi500_close,
                                            self.a50_close,
                                            self.if_close[0],
                                            self.ic_close[0],
                                            self.cn_close[0],
                                            self.getpositionbyname('IF').size,
                                            self.getpositionbyname('IC').size,
                                            self.getpositionbyname('CN').size,
                                            self.broker.get_cash(),
                                            self.broker.get_value()
                                       )
        )
    def notify_order(self, order):  
        if order.status in [order.Completed]:
            ops = None
            
            if order.isbuy():
                ops = 'Buy'
            elif order.issell():
                ops = 'Sell'
            if order.isbuy():
                self.log('BUY EXECUTED,%s,%s,%.2f,%d,%.2f,%d,%d,%s,%.2f\n' % ( 
                                                        order.data._name,
                                                        bt.num2date(order.executed.dt),
                                                        order.executed.price,
                                                        order.executed.size,
                                                        order.executed.pnl,
                                                        order.executed.psize,
                                                        order.executed.comm,
                                                        order.ref,
                                                        self.broker.get_value())
                                                    )

            else:  # Sell
                self.log('SELL EXECUTED,%s,%s,%.2f,%d,%.2f,%d,%d,%s,%.2f\n' % ( 
                                                        order.data._name,
                                                        bt.num2date(order.executed.dt),
                                                        order.executed.price,
                                                        order.executed.size,
                                                        order.executed.pnl,
                                                        order.executed.psize,
                                                        order.executed.comm,
                                                        order.ref,
                                                        self.broker.get_value())
                                                    )
            self.tradeLog.write('%s,%s,%s,%.2f,%d,%.2f,%d,%d,%d,%s,%.2f\n' % (
                                                        order.data._name,
                                                        bt.num2date(order.executed.dt),
                                                        ops,
                                                        order.executed.price,
                                                        order.executed.size,
                                                        order.executed.pnl,
                                                        self.base,
                                                        order.executed.psize,
                                                        order.executed.comm,
                                                        order.ref,
                                                        self.broker.get_value())
                                                    )
        self.order = None
        # Sentinel to None: new orders allowed
    def __init__(self):
        self.tradeLog = open('tradelog/'+self.p.logname, 'w+')
        self.tradeLog.write('Symbol,Dates,Trade,Price,Size,PnL,Base,CurrentPos,Comm,ref,Value\n')
        self.portlog = open('portlog/'+self.p.logname, 'w+')
        self.portlog.write('Datetime,CSI300,CSI500,A50,IF,IC,CN,IF_pos,IC_pos,CN_pos,Cash,Value\n')
        self.order = None
        self.traded = False
        self.if_close = self.data0.close
        self.ic_close = self.data1.close
        self.cn_close = self.data2.close
        self.csi300_close = None
        self.csi500_close = None
        self.a50_close = None
        self.cn_theo = None 
        self.theo_spread = None 
        self.lots_int = None
        self.base = 0
        self.week = 0

    def next(self):
        if self.csi300_close is None or self.csi500_close is None or self.a50_close is None:
            if self.datetime.time() == datetime.time(hour = 9, minute=30):
                self.csi300_close = self.data3.close[0]
                self.csi500_close = self.data4.close[0]
                self.a50_close = self.data5.close[0]
            # self.log("%.2f,%.2f,%.2f,%.2f,%.2f,%.d,%.d"%(self.if_close[0],self.ic_close[0],self.cn_close[0],cn_ask,cn_bid,self.base,self.broker.get_value()))
            self.write_record()
        else:
            # print(self.datetime.date().weekday())
            
            if self.data.datetime.datetime() in if_rolldate:# or self.data.datetime.datetime() in cn_rolldate:#and self.datetime.date().isocalendar()[1] >= self.week+4:
                # self.week = self.datetime.date().isocalendar()[1]
                self.csi300_close = self.data3.close[0]
                self.csi500_close = self.data4.close[0]
                self.a50_close = self.data5.close[0]
            self.cn_theo = self.a50_close*(self.p.if_lot*3*self.if_close[0] - self.p.ic_lot*2*self.ic_close[0])/(self.p.if_lot*3*self.csi300_close-self.p.ic_lot*2*self.csi500_close)
            cn_bid = self.cn_theo - self.p.margin + self.base
            cn_ask = self.cn_theo + self.p.margin + self.base
            self.log("%.2f,%.2f,%.2f,%.2f,%.2f,%.d,%.d"%(self.if_close[0],self.ic_close[0],self.cn_close[0],cn_ask,cn_bid,self.base,self.broker.get_value()))
            self.write_record()

            if self.cn_close > cn_ask: # 市场价 大于 理论卖价，市场价过高， 按照市场价卖出CN
                size = (self.cn_close - cn_ask)//self.p.distor + 1 # size > 0
                self.buy( data = self.getdatabyname('IF'),
                        size = self.p.if_lot*size,
                        exectype=bt.Order.Market,coc=True)
                self.sell( data = self.getdatabyname('IC'),
                        size = self.p.ic_lot*size,
                        exectype=bt.Order.Market,coc=True)
                self.sell( data = self.getdatabyname('CN'),
                        size = self.p.cn_lot*size, # size < 0
                        exectype=bt.Order.Market,coc=True)
                self.base = self.base + size * self.p.distor # base 上移，抬高理论价
                
            if self.cn_close < cn_bid: # 市场价 小于 理论买价，市场价过低，按照市场价买入
                size = (cn_bid - self.cn_close)//self.p.distor + 1 # size > 0
                self.sell( data = self.getdatabyname('IF'),
                        size = self.p.if_lot*size,
                        exectype=bt.Order.Market,coc=True)
                self.buy( data = self.getdatabyname('IC'),
                        size = self.p.ic_lot*size,
                        exectype=bt.Order.Market,coc=True)
                self.buy( data = self.getdatabyname('CN'),
                        size = self.p.cn_lot*size, # size < 0
                        exectype=bt.Order.Market,coc=True)
                self.base = self.base - size * self.p.distor

            if self.data.datetime.datetime()+datetime.timedelta(minutes=1) in if_rolldate:
                self.base = 0

                if self.getpositionbyname('IF').size != 0:
                    self.order_target_size( data = self.getdatabyname('IF'),
                                            target= 0,
                                            exectype=bt.Order.Market,
                                            coc = True)
                if self.getpositionbyname('IC').size != 0:
                    self.order_target_size( data = self.getdatabyname('IC'),
                                            target= 0,
                                            exectype=bt.Order.Market,
                                            coc = True)
                if self.getpositionbyname('CN').size != 0:
                    self.order_target_size( data = self.getdatabyname('CN'),
                                            target= 0,
                                            exectype=bt.Order.Market,
                                            coc = True)
            if self.data.datetime.datetime()+datetime.timedelta(minutes=1) in cn_rolldate:
                self.base = 0
                if self.getpositionbyname('IF').size != 0:
                    self.order_target_size( data = self.getdatabyname('IF'),
                                            target= 0,
                                            exectype=bt.Order.Market,
                                            coc = True)
                if self.getpositionbyname('IC').size != 0:
                    self.order_target_size( data = self.getdatabyname('IC'),
                                            target= 0,
                                            exectype=bt.Order.Market,
                                            coc = True)
                if self.getpositionbyname('CN').size != 0:
                    self.order_target_size( data = self.getdatabyname('CN'),
                                            target= 0,
                                            exectype=bt.Order.Market,
                                            coc = True)


    # def next_open(self):
        # 换月重新开仓
    #     # if self.data.datetime.datetime()in if_rolldate:  
    #             self.buy(data=self.getdatabyname('IF'),exectype=bt.Order.Market,coo = True)
    #             self.buy(data=self.getdatabyname('IC'),exectype=bt.Order.Market,coo = True)
    #     if self.data.datetime.datetime()in cn_rolldate:  
    #             self.buy(data=self.getdatabyname('CN'),exectype=bt.Order.Market,coo = True)
    def stop(self):
        self.tradeLog.close()
        self.portlog.close()

# %%
class IFICReplayStrategy(bt.Strategy):
    params = (

        ('margin', 25),  
        ('distor', 5),
        ('bias', 0),
        ('if_lot',3),
        ('ic_lot',1),
        ('cn_lot',30),
        ('logname','abs.csv'),

    )
    def start(self):
        header = [ 'len','Name','Code', 'Datetime', 'WeekDay', 'Open',
                  'High', 'Low', 'Close', 'Volume', 'OpenInterest']
        print(', '.join(header))

    def log(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.datetime()
        print('%s, %s' % (dt.isoformat(), txt))
    
    def write_record(self, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.datetime()
        self.portlog.write('%s, %.1f, %.1f, %.1f, %.1f, %.1f, %.1f,%d, %d, %d, %d, %d\n' 
                                        % ( dt.isoformat(),
                                            self.csi300_close,
                                            self.csi500_close,
                                            self.a50_close,
                                            self.if_close[0],
                                            self.ic_close[0],
                                            self.cn_close[0],
                                            self.getpositionbyname('IF').size,
                                            self.getpositionbyname('IC').size,
                                            self.getpositionbyname('CN').size,
                                            self.broker.get_cash(),
                                            self.broker.get_value()
                                       )
        )
    def notify_order(self, order):  
        if order.status in [order.Completed]:
            ops = None
            
            if order.isbuy():
                ops = 'Buy'
            elif order.issell():
                ops = 'Sell'
            if order.isbuy():
                self.log('BUY EXECUTED,%s,%s,%.2f,%d,%.2f,%d,%d,%s,%.2f\n' % ( 
                                                        order.data._name,
                                                        bt.num2date(order.executed.dt),
                                                        order.executed.price,
                                                        order.executed.size,
                                                        order.executed.pnl,
                                                        order.executed.psize,
                                                        order.executed.comm,
                                                        order.ref,
                                                        self.broker.get_value())
                                                    )

            else:  # Sell
                self.log('SELL EXECUTED,%s,%s,%.2f,%d,%.2f,%d,%d,%s,%.2f\n' % ( 
                                                        order.data._name,
                                                        bt.num2date(order.executed.dt),
                                                        order.executed.price,
                                                        order.executed.size,
                                                        order.executed.pnl,
                                                        order.executed.psize,
                                                        order.executed.comm,
                                                        order.ref,
                                                        self.broker.get_value())
                                                    )
            self.tradeLog.write('%s,%s,%s,%.2f,%d,%.2f,%d,%d,%d,%s,%.2f\n' % (
                                                        order.data._name,
                                                        bt.num2date(order.executed.dt),
                                                        ops,
                                                        order.executed.price,
                                                        order.executed.size,
                                                        order.executed.pnl,
                                                        self.base,
                                                        order.executed.psize,
                                                        order.executed.comm,
                                                        order.ref,
                                                        self.broker.get_value())
                                                    )
        self.order = None
        # Sentinel to None: new orders allowed
    def __init__(self):
        self.tradeLog = open('tradelog/'+self.p.logname, 'w+')
        self.tradeLog.write('Symbol,Dates,Trade,Price,Size,PnL,Base,CurrentPos,Comm,ref,Value\n')
        self.portlog = open('portlog/'+self.p.logname, 'w+')
        self.portlog.write('Datetime,CSI300,CSI500,A50,IF,IC,CN,IF_pos,IC_pos,CN_pos,Cash,Value\n')
        self.order = None
        self.traded = False
        self.if_close = self.data0.close
        self.ic_close = self.data1.close
        self.cn_close = self.data2.close
        self.csi300_close = None
        self.csi500_close = None
        self.a50_close = None
        self.cn_theo = None 
        self.theo_spread = None 
        self.lots_int = None
        self.base = 0
        self.week = 0

    def next(self):
        if self.csi300_close is None or self.csi500_close is None or self.a50_close is None:
            if self.datetime.time() == datetime.time(hour = 9, minute=30):
                self.csi300_close = self.data3.close[0]
                self.csi500_close = self.data4.close[0]
                self.a50_close = self.data5.close[0]
            # self.log("%.2f,%.2f,%.2f,%.2f,%.2f,%.d,%.d"%(self.if_close[0],self.ic_close[0],self.cn_close[0],cn_ask,cn_bid,self.base,self.broker.get_value()))
            self.write_record()
        else:
            # print(self.datetime.date().weekday())
            
            if self.data.datetime.datetime() in if_rolldate:# or self.data.datetime.datetime() in cn_rolldate:#and self.datetime.date().isocalendar()[1] >= self.week+4:
                # self.week = self.datetime.date().isocalendar()[1]
                self.csi300_close = self.data3.close[0]
                self.csi500_close = self.data4.close[0]
                self.a50_close = self.data5.close[0]
            self.cn_theo = self.a50_close*(self.p.if_lot*3*self.if_close[0] - self.p.ic_lot*2*self.ic_close[0])/(self.p.if_lot*3*self.csi300_close-self.p.ic_lot*2*self.csi500_close)
            cn_bid = self.cn_theo - self.p.margin + self.base
            cn_ask = self.cn_theo + self.p.margin + self.base
            self.log("%.2f,%.2f,%.2f,%.2f,%.2f,%.d,%.d"%(self.if_close[0],self.ic_close[0],self.cn_close[0],cn_ask,cn_bid,self.base,self.broker.get_value()))
            self.write_record()

            

            if self.data.datetime.datetime()+datetime.timedelta(minutes=1) in if_rolldate:
                self.base = 0

                if self.getpositionbyname('IF').size != 0:
                    self.order_target_size( data = self.getdatabyname('IF'),
                                            target= 0,
                                            exectype=bt.Order.Market,
                                            coc = True)
                if self.getpositionbyname('IC').size != 0:
                    self.order_target_size( data = self.getdatabyname('IC'),
                                            target= 0,
                                            exectype=bt.Order.Market,
                                            coc = True)
                if self.getpositionbyname('CN').size != 0:
                    self.order_target_size( data = self.getdatabyname('CN'),
                                            target= 0,
                                            exectype=bt.Order.Market,
                                            coc = True)
            if self.data.datetime.datetime()+datetime.timedelta(minutes=1) in cn_rolldate:
                self.base = 0
                if self.getpositionbyname('IF').size != 0:
                    self.order_target_size( data = self.getdatabyname('IF'),
                                            target= 0,
                                            exectype=bt.Order.Market,
                                            coc = True)
                if self.getpositionbyname('IC').size != 0:
                    self.order_target_size( data = self.getdatabyname('IC'),
                                            target= 0,
                                            exectype=bt.Order.Market,
                                            coc = True)
                if self.getpositionbyname('CN').size != 0:
                    self.order_target_size( data = self.getdatabyname('CN'),
                                            target= 0,
                                            exectype=bt.Order.Market,
                                            coc = True)


    # def next_open(self):
        # 换月重新开仓
    #     # if self.data.datetime.datetime()in if_rolldate:  
    #             self.buy(data=self.getdatabyname('IF'),exectype=bt.Order.Market,coo = True)
    #             self.buy(data=self.getdatabyname('IC'),exectype=bt.Order.Market,coo = True)
    #     if self.data.datetime.datetime()in cn_rolldate:  
    #             self.buy(data=self.getdatabyname('CN'),exectype=bt.Order.Market,coo = True)
    def stop(self):
        self.tradeLog.close()
        self.portlog.close()

# %%
from tabulate import tabulate

cerebro = bt.Cerebro(cheat_on_open = True)
cerebro.broker.set_coc(True)
cerebro.broker.set_cash(100000000)
cerebro.broker.set_shortcash(False)

cerebro.rolloverdata(name='IF', *if_feeds,checkdate = if_expire,fromdate=st_date,todate=ed_date)
cerebro.rolloverdata(name='IC', *ic_feeds,checkdate = if_expire,fromdate=st_date,todate=ed_date,)
cerebro.rolloverdata(name='CN', *cn_feeds,checkdate = cn_expire,fromdate=st_date,todate=ed_date,)
cerebro.adddata(csi300_feed)
cerebro.adddata(csi500_feed)
cerebro.adddata(a50_feed)

cerebro.broker.setcommission(commission=30,
                             commtype=bt.CommInfoBase.COMM_FIXED,
                             mult=300,
                             margin=150000,
                             name='IF')
cerebro.broker.setcommission(commission=27,
                             commtype=bt.CommInfoBase.COMM_FIXED,
                             mult=200,
                             margin=160000,
                             name='IC')
cerebro.broker.setcommission(commission=10.5,
                             commtype=bt.CommInfoBase.COMM_FIXED,
                             mult=6.8,
                             margin=10000,
                             name='CN')
cerebro.addstrategy(IFICReplayStrategy,if_lot = 0.000001,cn_lot = 0.000001,ic_lot = 0.000001,logname = 'replay_523-610.csv')
cerebro.add_order_history(tradelist, notify=True)

# cerebro.addstrategy(IFICAbsRollStrategy,if_lot = 2,cn_lot = 14,logname = '2IF_IC_27CN_Roll_523-610.csv')
strats = cerebro.run(runonce = False,cheat_on_open=True,tradehistory = True)

# %%
port_record_set = {}
port_record = pd.read_csv('portlog/2IF_IC_27CN_ROLL_523-610.csv')
port_record = port_record[['Datetime','CSI300','CSI500','A50','IF','IC','CN','IF_pos','IC_pos','CN_pos','Cash','Value']]
port_record.set_index('Datetime',inplace=True)
port_record = port_record.dropna()
port_record.index = pd.to_datetime(port_record.index)

port_record_set['Roll'] = port_record


# port_record = pd.read_csv('portlog/3IF_IC_27CN_ABS_ROLLN_JUN_10.csv')
# port_record = port_record[['Datetime','CSI300','CSI500','A50','IF','IC','CN','IF_pos','IC_pos','CN_pos','Cash','Value']]
# port_record.set_index('Datetime',inplace=True)
# port_record = port_record.dropna()
# port_record.index = pd.to_datetime(port_record.index)

# port_record_set['RollN'] = port_record


# abs_port_record = pd.read_csv('portlog/3IF_IC_27CN_ABS_DailyC_JUN_10.csv')
# abs_port_record = abs_port_record[['Datetime','CSI300','CSI500','A50','IF','IC','CN','IF_pos','IC_pos','CN_pos','Cash','Value']]
# abs_port_record.set_index('Datetime',inplace=True)
# abs_port_record = abs_port_record.dropna()
# abs_port_record.index = pd.to_datetime(abs_port_record.index)

# port_record_set['DailyClose'] = abs_port_record

port_record = pd.read_csv('portlog/2IF_IC_27CN_DailyO_523-610.csv')
port_record = port_record[['Datetime','CSI300','CSI500','A50','IF','IC','CN','IF_pos','IC_pos','CN_pos','Cash','Value']]
port_record.set_index('Datetime',inplace=True)
port_record = port_record.dropna()
port_record.index = pd.to_datetime(port_record.index)

port_record_set['DailyOpen'] = port_record



port_record = pd.read_csv('portlog/2IF_IC_27CN_Basis_523-610.csv')
port_record = port_record[['Datetime','CSI300','CSI500','A50','IF','IC','CN','IF_pos','IC_pos','CN_pos','Cash','Value']]
port_record.set_index('Datetime',inplace=True)
port_record = port_record.dropna()
port_record.index = pd.to_datetime(port_record.index)

port_record_set['Basis'] = port_record

# %%
for k in port_record_set.keys():
    port_record_set[k] = port_record_set[k].loc['2022-06-01':]

# %%
tf = pd.read_csv('tradeinfo.csv',parse_dates = True,infer_datetime_format=True,header=None)

# %%
tf.columns = ['datetime','dir','ct','price','lot','dd','tp','info','g','ddd']
tf = tf.set_index('datetime')

# %%
tf.index = pd.to_datetime(tf.index,format='%Y-%m-%d_%H:%M:%S.%f')

# %%
tf
# Out:
#                           dir           ct    price  lot   dd  tp   info  \
# datetime
# 2022-05-23 09:30:12.868  sell  SGX_CN_2205  13530.0    6  dir   2  info=
# 2022-05-23 09:30:12.920  sell  SGX_CN_2205  13530.0   21  dir   2  info=
# 2022-05-23 09:30:12.941   buy       IF2206   4054.8    1  dir   1  info=
# 2022-05-23 09:30:12.942   buy       IF2206   4055.0    1  dir   1  info=
# 2022-05-23 09:30:12.942   buy       IF2206   4055.0    1  dir   1  info=
# ...                       ...          ...      ...  ...  ...  ..    ...
# 2022-06-10 14:45:50.283   buy  SGX_CN_2206  14079.0   16  dir   1  info=
# 2022-06-10 14:45:50.305   buy  SGX_CN_2206  14079.0   11  dir   1  info=
# 2022-06-10 14:45:50.309  sell       IF2206   4242.8    1  dir   2  info=
# 2022-06-10 14:45:50.314  sell       IF2206   4242.8    2  dir   2  info=
# 2022-06-10 14:45:50.316   buy       IC2206   6250.0    1  dir   1  info=
#
#                                 g     ddd
# datetime
# 2022-05-23 09:30:12.868  13080.30     NaN
# 2022-05-23 09:30:12.920  13080.30     NaN
# 2022-05-23 09:30:12.941   3938.76  4054.8
# 2022-05-23 09:30:12.942   3938.76  4054.8
# 2022-05-23 09:30:12.942   3938.76  4054.8
# ...                           ...     ...
# 2022-06-10 14:45:50.283  14103.60     NaN
# 2022-06-10 14:45:50.305  14103.60     NaN
# 2022-06-10 14:45:50.309   4239.43  4242.8
# 2022-06-10 14:45:50.314   4239.43  4242.8
# 2022-06-10 14:45:50.316   6247.19  6250.2
#
# [1259 rows x 9 columns]

# %%
tradelist
# Out:
# [(Timestamp('2022-05-23 09:30:12.868000'), -6, 13530.0, 'CN'),
#  (Timestamp('2022-05-23 09:30:12.920000'), -21, 13530.0, 'CN'),
#  (Timestamp('2022-05-23 09:30:12.941000'), -1, 4054.8, 'IF'),
#  (Timestamp('2022-05-23 09:30:12.942000'), -1, 4055.0, 'IF'),
#  (Timestamp('2022-05-23 09:30:12.942000'), -1, 4055.0, 'IF'),
#  (Timestamp('2022-06-10 09:31:16.499000'), -1, 4144.0, 'IF'),
#  (Timestamp('2022-06-10 09:31:16.970000'), -1, 6082.6, 'IC'),
#  (Timestamp('2022-06-10 09:49:03.275000'), -11, 13770.0, 'CN'),
#  (Timestamp('2022-06-10 09:49:03.276000'), -8, 13770.0, 'CN'),
#  (Timestamp('2022-06-10 09:49:03.286000'), -1, 6104.0, 'IC'),
#  (Timestamp('2022-06-10 09:49:03.296000'), -8, 13770.0, 'CN'),
#  (Timestamp('2022-06-10 09:49:07.004000'), -1, 4154.6, 'IF'),
#  (Timestamp('2022-06-10 09:49:07.009000'), -1, 4154.6, 'IF'),
#  (Timestamp('2022-06-10 09:49:07.011000'), -1, 4154.6, 'IF'),
#  ...]

# %%
# tf.index = pd.to_datetime(tf.index)
tf = tf.loc['2022-5-23':'2022-6-12']
tradelist = []
for idx,r in tf.iterrows():
    print(r)
    ct = 'CN'
    if 'IF' in r['ct']:
        ct = 'IF'
    if 'IC' in r['ct']:
        ct = 'IC'
    size = r['lot'] if r['dir'] is 'buy' else -r['lot']
    tradelist.append(
                        (
                        idx,#datetime.datetime.strftime(idx,'%Y-%m-%d %H:%M:%S'),
                        size,
                        r['price'],
                        ct
                        )
                    )
# Out:
# <>:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Windows\Temp\ipykernel_20076\1860709297.py:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   size = r['lot'] if r['dir'] is 'buy' else -r['lot']
# dir             sell
# ct       SGX_CN_2205
# price          13530
# lot                6
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:30:12.868000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13530
# lot               21
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:30:12.920000, dtype: object
# dir          buy
# ct        IF2206
# price     4054.8
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       4054.8
# Name: 2022-05-23 09:30:12.941000, dtype: object
# dir          buy
# ct        IF2206
# price       4055
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       4054.8
# Name: 2022-05-23 09:30:12.942000, dtype: object
# dir          buy
# ct        IF2206
# price       4055
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       4054.8
# Name: 2022-05-23 09:30:12.942000, dtype: object
# dir        sell
# ct       IC2206
# price    5878.6
# lot           1
# dd          dir
# tp            2
# info      info=
# g          5709
# ddd      5878.6
# Name: 2022-05-23 09:30:12.943000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13517
# lot               21
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:30:47.010000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13517
# lot                2
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:30:47.011000, dtype: object
# dir          buy
# ct        IF2206
# price     4050.4
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       4050.6
# Name: 2022-05-23 09:30:47.023000, dtype: object
# dir          buy
# ct        IF2206
# price     4050.6
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       4050.6
# Name: 2022-05-23 09:30:47.023000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13517
# lot                4
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:30:47.030000, dtype: object
# dir          buy
# ct        IF2206
# price     4050.6
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       4050.6
# Name: 2022-05-23 09:30:47.054000, dtype: object
# dir        sell
# ct       IC2206
# price    5876.4
# lot           1
# dd          dir
# tp            2
# info      info=
# g          5709
# ddd      5876.2
# Name: 2022-05-23 09:30:47.055000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13489
# lot               27
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:31:19.718000, dtype: object
# dir          buy
# ct        IF2206
# price     4043.8
# lot            2
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       4043.8
# Name: 2022-05-23 09:31:19.738000, dtype: object
# dir          buy
# ct        IF2206
# price     4043.8
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       4043.8
# Name: 2022-05-23 09:31:19.739000, dtype: object
# dir        sell
# ct       IC2206
# price    5880.2
# lot           1
# dd          dir
# tp            2
# info      info=
# g          5709
# ddd        5880
# Name: 2022-05-23 09:31:19.739000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13496
# lot                8
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:32:03.707000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13496
# lot               19
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:32:03.813000, dtype: object
# dir          buy
# ct        IF2206
# price     4044.2
# lot            3
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       4044.2
# Name: 2022-05-23 09:32:03.828000, dtype: object
# dir        sell
# ct       IC2206
# price      5877
# lot           1
# dd          dir
# tp            2
# info      info=
# g          5709
# ddd        5877
# Name: 2022-05-23 09:32:03.828000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13505
# lot               27
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:32:35.720000, dtype: object
# dir        sell
# ct       IC2206
# price      5869
# lot           1
# dd          dir
# tp            2
# info      info=
# g          5709
# ddd      5868.4
# Name: 2022-05-23 09:32:35.744000, dtype: object
# dir          buy
# ct        IF2206
# price       4043
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       4042.6
# Name: 2022-05-23 09:32:35.897000, dtype: object
# dir          buy
# ct        IF2206
# price     4043.2
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       4042.6
# Name: 2022-05-23 09:32:37.228000, dtype: object
# dir          buy
# ct        IF2206
# price     4043.2
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       4042.6
# Name: 2022-05-23 09:32:37.319000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13501
# lot                1
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:33:17.823000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13501
# lot                2
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:33:17.824000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13501
# lot                2
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:33:17.844000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13501
# lot                1
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:33:17.845000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13501
# lot               20
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:33:19.215000, dtype: object
# dir          buy
# ct        IF2206
# price     4041.8
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       4041.2
# Name: 2022-05-23 09:33:19.230000, dtype: object
# dir          buy
# ct        IF2206
# price     4041.8
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       4041.2
# Name: 2022-05-23 09:33:19.232000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13501
# lot                1
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:33:19.424000, dtype: object
# dir          buy
# ct        IF2206
# price     4041.8
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       4041.2
# Name: 2022-05-23 09:33:19.449000, dtype: object
# dir        sell
# ct       IC2206
# price    5875.2
# lot           1
# dd          dir
# tp            2
# info      info=
# g          5709
# ddd      5875.8
# Name: 2022-05-23 09:33:19.648000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13474
# lot                1
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:35:10.266000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13474
# lot                4
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:35:10.267000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13474
# lot                1
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:35:10.287000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13474
# lot               19
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:35:10.287000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13474
# lot                2
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:35:10.288000, dtype: object
# dir          buy
# ct        IF2206
# price     4034.4
# lot            2
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       4034.4
# Name: 2022-05-23 09:35:10.299000, dtype: object
# dir          buy
# ct        IF2206
# price     4034.4
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       4034.4
# Name: 2022-05-23 09:35:10.300000, dtype: object
# dir        sell
# ct       IC2206
# price    5872.4
# lot           1
# dd          dir
# tp            2
# info      info=
# g          5709
# ddd      5870.8
# Name: 2022-05-23 09:35:10.300000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13485
# lot                1
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:41:25.801000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13471
# lot                1
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:45:47.735000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13471
# lot                4
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:45:47.757000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13471
# lot                1
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:45:47.757000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13471
# lot                1
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:45:47.757000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13471
# lot                5
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:45:47.760000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13471
# lot                6
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:45:47.761000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13471
# lot                6
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:45:47.761000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13471
# lot                2
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:45:47.762000, dtype: object
# dir        sell
# ct       IC2206
# price      5873
# lot           1
# dd          dir
# tp            2
# info      info=
# g          5709
# ddd      5871.2
# Name: 2022-05-23 09:45:47.780000, dtype: object
# dir          buy
# ct        IF2206
# price     4033.2
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       4032.6
# Name: 2022-05-23 09:45:47.910000, dtype: object
# dir          buy
# ct        IF2206
# price     4033.2
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       4032.6
# Name: 2022-05-23 09:45:50.132000, dtype: object
# dir          buy
# ct        IF2206
# price     4035.2
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       4032.6
# Name: 2022-05-23 09:45:53.681000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13479
# lot                4
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:52:58.688000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13479
# lot               23
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 09:52:58.689000, dtype: object
# dir          buy
# ct        IF2206
# price     4035.2
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       4035.2
# Name: 2022-05-23 09:52:58.702000, dtype: object
# dir          buy
# ct        IF2206
# price     4035.2
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       4035.2
# Name: 2022-05-23 09:52:58.703000, dtype: object
# dir          buy
# ct        IF2206
# price     4035.2
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       4035.2
# Name: 2022-05-23 09:52:58.703000, dtype: object
# dir        sell
# ct       IC2206
# price      5881
# lot           1
# dd          dir
# tp            2
# info      info=
# g          5709
# ddd      5880.8
# Name: 2022-05-23 09:52:58.703000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13358
# lot               27
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 10:28:06.261000, dtype: object
# dir         sell
# ct        IF2206
# price       4012
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd       4012.2
# Name: 2022-05-23 10:28:06.277000, dtype: object
# dir         sell
# ct        IF2206
# price       4012
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd       4012.2
# Name: 2022-05-23 10:28:06.278000, dtype: object
# dir         sell
# ct        IF2206
# price     4011.8
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd       4012.2
# Name: 2022-05-23 10:28:06.278000, dtype: object
# dir         buy
# ct       IC2206
# price      5853
# lot           1
# dd          dir
# tp            1
# info      info=
# g          5709
# ddd      5853.8
# Name: 2022-05-23 10:28:06.278000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13352
# lot               27
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 11:01:00.929000, dtype: object
# dir         sell
# ct        IF2206
# price     4013.2
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd       4013.4
# Name: 2022-05-23 11:01:00.945000, dtype: object
# dir         sell
# ct        IF2206
# price       4013
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd       4013.4
# Name: 2022-05-23 11:01:00.945000, dtype: object
# dir         sell
# ct        IF2206
# price       4013
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd       4013.4
# Name: 2022-05-23 11:01:00.945000, dtype: object
# dir         buy
# ct       IC2206
# price    5863.2
# lot           1
# dd          dir
# tp            1
# info      info=
# g          5709
# ddd      5863.2
# Name: 2022-05-23 11:01:00.946000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13389
# lot               10
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 13:47:56.400000, dtype: object
# dir          buy
# ct        IF2206
# price       4019
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd         4019
# Name: 2022-05-23 13:47:56.426000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13389
# lot                1
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 13:47:56.662000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13389
# lot                1
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 13:47:56.768000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13389
# lot                1
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 13:47:56.979000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13389
# lot                2
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 13:47:57.030000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13389
# lot                5
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 13:47:57.660000, dtype: object
# dir          buy
# ct        IF2206
# price     4019.2
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       4019.2
# Name: 2022-05-23 13:47:57.673000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13389
# lot                7
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 13:47:57.719000, dtype: object
# dir          buy
# ct        IF2206
# price     4019.2
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       4019.2
# Name: 2022-05-23 13:47:57.735000, dtype: object
# dir        sell
# ct       IC2206
# price    5887.6
# lot           1
# dd          dir
# tp            2
# info      info=
# g          5709
# ddd      5887.4
# Name: 2022-05-23 13:47:57.735000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13407
# lot               21
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 13:49:34.774000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13407
# lot                6
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-23 13:49:34.777000, dtype: object
# dir          buy
# ct        IF2206
# price     4022.4
# lot            2
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       4022.2
# Name: 2022-05-23 13:49:34.804000, dtype: object
# dir          buy
# ct        IF2206
# price     4022.6
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       4022.2
# Name: 2022-05-23 13:49:34.804000, dtype: object
# dir        sell
# ct       IC2206
# price    5891.6
# lot           1
# dd          dir
# tp            2
# info      info=
# g          5709
# ddd      5891.4
# Name: 2022-05-23 13:49:34.805000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13357
# lot               10
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 09:41:14.187000, dtype: object
# dir         sell
# ct        IF2206
# price     4018.2
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd         4018
# Name: 2022-05-24 09:41:14.205000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13367
# lot                8
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 09:41:31.125000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13367
# lot                4
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 09:41:31.126000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13367
# lot                2
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 09:41:31.128000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13367
# lot                3
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 09:41:31.129000, dtype: object
# dir         sell
# ct        IF2206
# price     4019.8
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd       4020.4
# Name: 2022-05-24 09:41:31.141000, dtype: object
# dir         sell
# ct        IF2206
# price     4019.8
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd       4020.4
# Name: 2022-05-24 09:41:31.148000, dtype: object
# dir         buy
# ct       IC2206
# price    5885.8
# lot           1
# dd          dir
# tp            1
# info      info=
# g          5709
# ddd        5886
# Name: 2022-05-24 09:41:31.148000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13300
# lot                8
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 10:04:39.123000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13300
# lot               19
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 10:04:39.542000, dtype: object
# dir         sell
# ct        IF2206
# price     4001.4
# lot            2
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd         4002
# Name: 2022-05-24 10:04:39.559000, dtype: object
# dir         buy
# ct       IC2206
# price    5857.2
# lot           1
# dd          dir
# tp            1
# info      info=
# g          5709
# ddd      5856.6
# Name: 2022-05-24 10:04:39.560000, dtype: object
# dir         sell
# ct        IF2206
# price     4001.4
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd         4002
# Name: 2022-05-24 10:04:39.812000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13314
# lot                3
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 10:06:12.493000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13314
# lot               24
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 10:06:12.494000, dtype: object
# dir         buy
# ct       IC2206
# price    5858.4
# lot           1
# dd          dir
# tp            1
# info      info=
# g          5709
# ddd      5858.8
# Name: 2022-05-24 10:06:12.510000, dtype: object
# dir         sell
# ct        IF2206
# price     4005.8
# lot            3
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd       4006.4
# Name: 2022-05-24 10:06:16.735000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13326
# lot                9
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 10:10:19.251000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13326
# lot               18
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 10:10:19.253000, dtype: object
# dir         buy
# ct       IC2206
# price    5865.8
# lot           1
# dd          dir
# tp            1
# info      info=
# g          5709
# ddd      5865.2
# Name: 2022-05-24 10:10:19.276000, dtype: object
# dir         sell
# ct        IF2206
# price     4011.6
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd       4012.2
# Name: 2022-05-24 10:10:19.592000, dtype: object
# dir         sell
# ct        IF2206
# price     4011.6
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd       4012.2
# Name: 2022-05-24 10:10:19.808000, dtype: object
# dir         sell
# ct        IF2206
# price     4011.6
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd       4012.2
# Name: 2022-05-24 10:10:19.837000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13298
# lot                6
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 10:31:13.880000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13298
# lot               17
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 10:31:13.880000, dtype: object
# dir         sell
# ct        IF2206
# price     4004.2
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd       4004.2
# Name: 2022-05-24 10:31:13.895000, dtype: object
# dir         sell
# ct        IF2206
# price     4003.8
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd       4004.2
# Name: 2022-05-24 10:31:13.895000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13298
# lot                4
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 10:31:13.901000, dtype: object
# dir         buy
# ct       IC2206
# price      5855
# lot           1
# dd          dir
# tp            1
# info      info=
# g          5709
# ddd      5855.8
# Name: 2022-05-24 10:31:13.929000, dtype: object
# dir         sell
# ct        IF2206
# price     4003.8
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd       4004.2
# Name: 2022-05-24 10:31:14.033000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13270
# lot               27
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 11:19:14.380000, dtype: object
# dir         sell
# ct        IF2206
# price       3988
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd         3988
# Name: 2022-05-24 11:19:14.401000, dtype: object
# dir         sell
# ct        IF2206
# price       3988
# lot            2
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd         3988
# Name: 2022-05-24 11:19:14.402000, dtype: object
# dir         buy
# ct       IC2206
# price      5799
# lot           1
# dd          dir
# tp            1
# info      info=
# g          5709
# ddd        5799
# Name: 2022-05-24 11:19:14.403000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13252
# lot               23
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 11:23:27.893000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13252
# lot                4
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 11:23:27.893000, dtype: object
# dir         sell
# ct        IF2206
# price     3982.6
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd         3983
# Name: 2022-05-24 11:23:27.916000, dtype: object
# dir         sell
# ct        IF2206
# price     3982.6
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd         3983
# Name: 2022-05-24 11:23:27.917000, dtype: object
# dir         sell
# ct        IF2206
# price     3982.4
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd         3983
# Name: 2022-05-24 11:23:27.917000, dtype: object
# dir         buy
# ct       IC2206
# price    5788.2
# lot           1
# dd          dir
# tp            1
# info      info=
# g          5709
# ddd        5788
# Name: 2022-05-24 11:23:27.918000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13206
# lot                1
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 13:00:05.746000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13206
# lot                2
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 13:00:05.853000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13206
# lot                3
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 13:00:05.905000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13206
# lot               21
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 13:00:05.906000, dtype: object
# dir         sell
# ct        IF2206
# price     3972.2
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd         3972
# Name: 2022-05-24 13:00:05.924000, dtype: object
# dir         sell
# ct        IF2206
# price       3972
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd         3972
# Name: 2022-05-24 13:00:05.926000, dtype: object
# dir         sell
# ct        IF2206
# price       3972
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd         3972
# Name: 2022-05-24 13:00:05.926000, dtype: object
# dir         buy
# ct       IC2206
# price    5777.8
# lot           1
# dd          dir
# tp            1
# info      info=
# g          5709
# ddd      5778.2
# Name: 2022-05-24 13:00:05.926000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13220
# lot                1
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 13:51:52.305000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13220
# lot               26
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 13:51:52.324000, dtype: object
# dir         sell
# ct        IF2206
# price       3973
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd         3973
# Name: 2022-05-24 13:51:52.343000, dtype: object
# dir         sell
# ct        IF2206
# price     3972.8
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd         3973
# Name: 2022-05-24 13:51:52.344000, dtype: object
# dir         sell
# ct        IF2206
# price     3972.8
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd         3973
# Name: 2022-05-24 13:51:52.344000, dtype: object
# dir         buy
# ct       IC2206
# price    5763.2
# lot           1
# dd          dir
# tp            1
# info      info=
# g          5709
# ddd      5763.6
# Name: 2022-05-24 13:51:52.344000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13205
# lot               18
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 14:07:41.786000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13205
# lot                2
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 14:07:41.788000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13205
# lot                7
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 14:07:41.788000, dtype: object
# dir         sell
# ct        IF2206
# price     3964.4
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd       3964.8
# Name: 2022-05-24 14:07:41.812000, dtype: object
# dir         sell
# ct        IF2206
# price     3964.4
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd       3964.8
# Name: 2022-05-24 14:07:41.813000, dtype: object
# dir         sell
# ct        IF2206
# price     3964.2
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd       3964.8
# Name: 2022-05-24 14:07:41.813000, dtype: object
# dir         buy
# ct       IC2206
# price    5734.2
# lot           1
# dd          dir
# tp            1
# info      info=
# g          5709
# ddd      5734.4
# Name: 2022-05-24 14:07:41.814000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13223
# lot                7
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 14:18:41.925000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13223
# lot                6
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 14:18:41.938000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13223
# lot               14
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 14:18:41.938000, dtype: object
# dir         buy
# ct       IC2206
# price      5723
# lot           1
# dd          dir
# tp            1
# info      info=
# g          5709
# ddd      5723.8
# Name: 2022-05-24 14:18:41.966000, dtype: object
# dir         sell
# ct        IF2206
# price       3967
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd         3967
# Name: 2022-05-24 14:18:41.970000, dtype: object
# dir         sell
# ct        IF2206
# price     3966.4
# lot            2
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd         3967
# Name: 2022-05-24 14:18:42.249000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13183
# lot               15
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 14:31:35.269000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13183
# lot                2
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 14:31:35.274000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13183
# lot                7
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 14:31:35.276000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13183
# lot                3
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-24 14:31:35.278000, dtype: object
# dir         sell
# ct        IF2206
# price     3955.6
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd       3955.8
# Name: 2022-05-24 14:31:35.293000, dtype: object
# dir         sell
# ct        IF2206
# price     3955.6
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd       3955.8
# Name: 2022-05-24 14:31:35.294000, dtype: object
# dir         sell
# ct        IF2206
# price     3955.6
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd       3955.8
# Name: 2022-05-24 14:31:35.295000, dtype: object
# dir         buy
# ct       IC2206
# price    5701.6
# lot           1
# dd          dir
# tp            1
# info      info=
# g          5709
# ddd      5701.8
# Name: 2022-05-24 14:31:35.296000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13169
# lot                7
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-25 09:31:07.766000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13169
# lot                6
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-25 09:31:07.766000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13169
# lot               14
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-25 09:31:07.768000, dtype: object
# dir         buy
# ct       IC2206
# price    5697.8
# lot           1
# dd          dir
# tp            1
# info      info=
# g          5709
# ddd      5697.8
# Name: 2022-05-25 09:31:07.785000, dtype: object
# dir         sell
# ct        IF2206
# price     3953.4
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd         3954
# Name: 2022-05-25 09:31:07.864000, dtype: object
# dir         sell
# ct        IF2206
# price     3953.4
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd         3954
# Name: 2022-05-25 09:31:07.870000, dtype: object
# dir         sell
# ct        IF2206
# price     3953.4
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd         3954
# Name: 2022-05-25 09:31:08.049000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13160
# lot                6
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-25 09:31:14.084000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13160
# lot                1
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-25 09:31:14.084000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13160
# lot                4
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-25 09:31:14.114000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13160
# lot                1
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-25 09:31:14.115000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13160
# lot                2
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-25 09:31:14.115000, dtype: object
# dir         sell
# ct        IF2206
# price     3949.6
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd         3950
# Name: 2022-05-25 09:31:14.137000, dtype: object
# dir              buy
# ct       SGX_CN_2205
# price          13160
# lot               13
# dd               dir
# tp                 1
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-25 09:31:14.138000, dtype: object
# dir         sell
# ct        IF2206
# price     3949.4
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd         3950
# Name: 2022-05-25 09:31:14.150000, dtype: object
# dir         buy
# ct       IC2206
# price    5697.4
# lot           1
# dd          dir
# tp            1
# info      info=
# g          5709
# ddd      5697.4
# Name: 2022-05-25 09:31:14.150000, dtype: object
# dir         sell
# ct        IF2206
# price     3949.4
# lot            1
# dd           dir
# tp             2
# info       info=
# g        3938.76
# ddd         3950
# Name: 2022-05-25 09:31:14.212000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13191
# lot               27
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-25 09:48:14.132000, dtype: object
# dir          buy
# ct        IF2206
# price     3952.4
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       3951.8
# Name: 2022-05-25 09:48:14.145000, dtype: object
# dir        sell
# ct       IC2206
# price    5699.8
# lot           1
# dd          dir
# tp            2
# info      info=
# g          5709
# ddd      5698.6
# Name: 2022-05-25 09:48:14.146000, dtype: object
# dir          buy
# ct        IF2206
# price     3952.4
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       3951.8
# Name: 2022-05-25 09:48:14.173000, dtype: object
# dir          buy
# ct        IF2206
# price     3952.4
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       3951.8
# Name: 2022-05-25 09:48:14.173000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13186
# lot                4
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-25 10:05:15.631000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13186
# lot                2
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-25 10:05:15.641000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13186
# lot                1
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-25 10:05:15.642000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13186
# lot                1
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-25 10:05:15.642000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13186
# lot                4
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-25 10:05:15.646000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13186
# lot               15
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-25 10:05:15.652000, dtype: object
# dir          buy
# ct        IF2206
# price     3954.6
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       3954.6
# Name: 2022-05-25 10:05:15.657000, dtype: object
# dir        sell
# ct       IC2206
# price      5723
# lot           1
# dd          dir
# tp            2
# info      info=
# g          5709
# ddd      5723.6
# Name: 2022-05-25 10:05:15.658000, dtype: object
# dir          buy
# ct        IF2206
# price     3954.6
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       3954.6
# Name: 2022-05-25 10:05:15.667000, dtype: object
# dir          buy
# ct        IF2206
# price     3954.6
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       3954.6
# Name: 2022-05-25 10:05:15.668000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13183
# lot               12
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-25 10:06:34.954000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13183
# lot                8
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-25 10:06:34.956000, dtype: object
# dir          buy
# ct        IF2206
# price     3952.4
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       3952.2
# Name: 2022-05-25 10:06:34.973000, dtype: object
# dir          buy
# ct        IF2206
# price     3952.4
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       3952.2
# Name: 2022-05-25 10:06:34.974000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13183
# lot                4
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-25 10:06:34.974000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13183
# lot                3
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-25 10:06:34.975000, dtype: object
# dir          buy
# ct        IF2206
# price     3952.4
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       3952.2
# Name: 2022-05-25 10:06:34.990000, dtype: object
# dir        sell
# ct       IC2206
# price    5720.2
# lot           1
# dd          dir
# tp            2
# info      info=
# g          5709
# ddd      5720.2
# Name: 2022-05-25 10:06:34.991000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13134
# lot               13
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-25 10:32:22.946000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13134
# lot                2
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-25 10:32:22.947000, dtype: object
# dir          buy
# ct        IF2206
# price     3938.6
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd         3938
# Name: 2022-05-25 10:32:22.960000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13134
# lot                2
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-25 10:32:22.965000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13134
# lot               10
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-25 10:32:22.966000, dtype: object
# dir          buy
# ct        IF2206
# price     3938.6
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd         3938
# Name: 2022-05-25 10:32:22.989000, dtype: object
# dir        sell
# ct       IC2206
# price    5706.8
# lot           1
# dd          dir
# tp            2
# info      info=
# g          5709
# ddd      5707.4
# Name: 2022-05-25 10:32:23.039000, dtype: object
# dir          buy
# ct        IF2206
# price     3938.6
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd         3938
# Name: 2022-05-25 10:32:23.040000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13175
# lot               27
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-25 13:19:44.909000, dtype: object
# dir          buy
# ct        IF2206
# price     3953.8
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       3953.8
# Name: 2022-05-25 13:19:44.935000, dtype: object
# dir          buy
# ct        IF2206
# price     3953.8
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       3953.8
# Name: 2022-05-25 13:19:44.935000, dtype: object
# dir          buy
# ct        IF2206
# price     3953.8
# lot            1
# dd           dir
# tp             1
# info       info=
# g        3938.76
# ddd       3953.8
# Name: 2022-05-25 13:19:44.935000, dtype: object
# dir        sell
# ct       IC2206
# price    5744.6
# lot           1
# dd          dir
# tp            2
# info      info=
# g          5709
# ddd      5744.6
# Name: 2022-05-25 13:19:44.936000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13130
# lot                1
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-25 13:43:16.062000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13130
# lot                5
# dd               dir
# tp                 2
# info           info=
# g            13080.3
# ddd              NaN
# Name: 2022-05-25 13:43:17.034000, dtype: object
# dir             sell
# ct       SGX_CN_2205
# price          13130
# lot               21
# dd               dir
# ...
# dd               dir
# tp                 1
# info           info=
# g            14043.5
# ddd              NaN
# Name: 2022-06-10 14:03:15.012000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14024
# lot                1
# dd               dir
# tp                 1
# info           info=
# g            14043.5
# ddd              NaN
# Name: 2022-06-10 14:03:15.013000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14025
# lot                1
# dd               dir
# tp                 1
# info           info=
# g            14043.5
# ddd              NaN
# Name: 2022-06-10 14:03:15.013000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14025
# lot                1
# dd               dir
# tp                 1
# info           info=
# g            14043.5
# ddd              NaN
# Name: 2022-06-10 14:03:15.014000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14025
# lot                6
# dd               dir
# tp                 1
# info           info=
# g            14043.5
# ddd              NaN
# Name: 2022-06-10 14:03:15.016000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14025
# lot                2
# dd               dir
# tp                 1
# info           info=
# g            14043.5
# ddd              NaN
# Name: 2022-06-10 14:03:15.017000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14025
# lot                2
# dd               dir
# tp                 1
# info           info=
# g            14043.5
# ddd              NaN
# Name: 2022-06-10 14:03:15.017000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14025
# lot                1
# dd               dir
# tp                 1
# info           info=
# g            14043.5
# ddd              NaN
# Name: 2022-06-10 14:03:15.028000, dtype: object
# dir         sell
# ct        IF2206
# price     4220.2
# lot            1
# dd           dir
# tp             2
# info       info=
# g        4223.49
# ddd       4220.2
# Name: 2022-06-10 14:03:15.031000, dtype: object
# dir         sell
# ct        IF2206
# price       4220
# lot            1
# dd           dir
# tp             2
# info       info=
# g        4223.49
# ddd       4220.2
# Name: 2022-06-10 14:03:15.032000, dtype: object
# dir         sell
# ct        IF2206
# price       4220
# lot            1
# dd           dir
# tp             2
# info       info=
# g        4223.49
# ddd       4220.2
# Name: 2022-06-10 14:03:15.036000, dtype: object
# dir          buy
# ct        IC2206
# price     6223.4
# lot            1
# dd           dir
# tp             1
# info       info=
# g        6225.74
# ddd       6223.4
# Name: 2022-06-10 14:03:15.036000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          
, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14027
# lot                1
# dd               dir
# tp                 1
# info           info=
# g            14047.7
# ddd              NaN
# Name: 2022-06-10 14:04:10.014000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14027
# lot                6
# dd               dir
# tp                 1
# info           info=
# g            14047.7
# ddd              NaN
# Name: 2022-06-10 14:04:10.017000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14027
# lot                3
# dd               dir
# tp                 1
# info           info=
# g            14047.7
# ddd              NaN
# Name: 2022-06-10 14:04:10.017000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14027
# lot                6
# dd               dir
# tp                 1
# info           info=
# g            14047.7
# ddd              NaN
# Name: 2022-06-10 14:04:10.018000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14027
# lot                1
# dd               dir
# tp                 1
# info           info=
# g            14047.7
# ddd              NaN
# Name: 2022-06-10 14:04:10.018000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14027
# lot                1
# dd               dir
# tp                 1
# info           info=
# g            14047.7
# ddd              NaN
# Name: 2022-06-10 14:04:10.019000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14027
# lot                2
# dd               dir
# tp                 1
# info           info=
# g            14047.7
# ddd              NaN
# Name: 2022-06-10 14:04:10.035000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14028
# lot                1
# dd               dir
# tp                 1
# info           info=
# g            14047.7
# ddd              NaN
# Name: 2022-06-10 14:04:10.035000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14028
# lot                1
# dd               dir
# tp                 1
# info           info=
# g            14047.7
# ddd              NaN
# Name: 2022-06-10 14:04:10.035000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14028
# lot                2
# dd               dir
# tp                 1
# info           info=
# g            14047.7
# ddd              NaN
# Name: 2022-06-10 14:04:10.036000, dtype: object
# dir         sell
# ct        IF2206
# price     4221.8
# lot            1
# dd           dir
# tp             2
# info       info=
# g        4223.47
# ddd       4221.8
# Name: 2022-06-10 14:04:10.039000, dtype: object
# dir         sell
# ct        IF2206
# price     4221.8
# lot            1
# dd           dir
# tp             2
# info       info=
# g        4223.47
# ddd       4221.8
# Name: 2022-06-10 14:04:10.039000, dtype: object
# dir         sell
# ct        IF2206
# price     4221.8
# lot            1
# dd           dir
# tp             2
# info       info=
# g        4223.47
# ddd       4221.8
# Name: 2022-06-10 14:04:10.044000, dtype: object
# dir          buy
# ct        IC2206
# price     6219.8
# lot            1
# dd           dir
# tp             1
# info       info=
# g        6223.83
# ddd       6219.8
# Name: 2022-06-10 14:04:10.044000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14025
# lot                1
# dd               dir
# tp                 1
# info           info=
# g            14046.4
# ddd              NaN
# Name: 2022-06-10 14:04:24.995000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14025
# lot                5
# dd               dir
# tp                 1
# info           info=
# g            14046.4
# ddd              NaN
# Name: 2022-06-10 14:04:25.016000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14025
# lot                1
# dd               dir
# tp                 1
# info           info=
# g            14046.4
# ddd              NaN
# Name: 2022-06-10 14:04:25.017000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14025
# lot                7
# dd               dir
# tp                 1
# info           info=
# g            14046.4
# ddd              NaN
# Name: 2022-06-10 14:04:25.017000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14025
# lot                1
# dd               dir
# tp                 1
# info           info=
# g            14046.4
# ddd              NaN
# Name: 2022-06-10 14:04:25.020000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14025
# lot                1
# dd               dir
# tp                 1
# info           info=
# g            14046.4
# ddd              NaN
# Name: 2022-06-10 14:04:25.020000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14025
# lot                6
# dd               dir
# tp                 1
# info           info=
# g            14046.4
# ddd              NaN
# Name: 2022-06-10 14:04:25.021000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14025
# lot                1
# dd               dir
# tp                 1
# info           info=
# g            14046.4
# ddd              NaN
# Name: 2022-06-10 14:04:25.021000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14025
# lot                2
# dd               dir
# tp                 1
# info           info=
# g            14046.4
# ddd              NaN
# Name: 2022-06-10 14:04:25.022000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14025
# lot                1
# dd               dir
# tp                 1
# info           info=
# g            14046.4
# ddd              NaN
# Name: 2022-06-10 14:04:25.022000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14026
# lot                1
# dd               dir
# tp                 1
# info           info=
# g            14046.4
# ddd              NaN
# Name: 2022-06-10 14:04:25.022000, dtype: object
# dir         sell
# ct        IF2206
# price       4222
# lot            1
# dd           dir
# tp             2
# info       info=
# g        4223.14
# ddd       4222.4
# Name: 2022-06-10 14:04:25.035000, dtype: object
# dir         sell
# ct        IF2206
# price       4222
# lot            1
# dd           dir
# tp             2
# info       info=
# g        4223.14
# ddd       4222.4
# Name: 2022-06-10 14:04:25.036000, dtype: object
# dir         sell
# ct        IF2206
# price     4221.8
# lot            1
# dd           dir
# tp             2
# info       info=
# g        4223.14
# ddd       4222.4
# Name: 2022-06-10 14:04:25.037000, dtype: object
# dir          buy
# ct        IC2206
# price     6221.8
# lot            1
# dd           dir
# tp             1
# info       info=
# g        6224.35
# ddd       6221.6
# Name: 2022-06-10 14:04:25.037000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14090
# lot               27
# dd               dir
# tp                 1
# info           info=
# g              14114
# ddd              NaN
# Name: 2022-06-10 14:18:03.921000, dtype: object
# dir         sell
# ct        IF2206
# price     4241.6
# lot            3
# dd           dir
# tp             2
# info       info=
# g        4239.25
# ddd       4241.6
# Name: 2022-06-10 14:18:03.944000, dtype: object
# dir          buy
# ct        IC2206
# price     6248.6
# lot            1
# dd           dir
# tp             1
# info       info=
# g        6246.36
# ddd       6248.6
# Name: 2022-06-10 14:18:04.100000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14079
# lot               16
# dd               dir
# tp                 1
# info           info=
# g            14103.6
# ddd              NaN
# Name: 2022-06-10 14:45:50.283000, dtype: object
# dir              buy
# ct       SGX_CN_2206
# price          14079
# lot               11
# dd               dir
# tp                 1
# info           info=
# g            14103.6
# ddd              NaN
# Name: 2022-06-10 14:45:50.305000, dtype: object
# dir         sell
# ct        IF2206
# price     4242.8
# lot            1
# dd           dir
# tp             2
# info       info=
# g        4239.43
# ddd       4242.8
# Name: 2022-06-10 14:45:50.309000, dtype: object
# dir         sell
# ct        IF2206
# price     4242.8
# lot            2
# dd           dir
# tp             2
# info       info=
# g        4239.43
# ddd       4242.8
# Name: 2022-06-10 14:45:50.314000, dtype: object
# dir          buy
# ct        IC2206
# price       6250
# lot            1
# dd           dir
# tp             1
# info       info=
# g        6247.19
# ddd       6250.2
# Name: 2022-06-10 14:45:50.316000, dtype: object

# %%
port_record = port_record.resample('5min').last().dropna()
totalPortValue = (
        Line(
                init_opts=opts.InitOpts(
                width="1440px",
                height="500px",
                animation_opts=opts.AnimationOpts(animation=False),
                )
        )
        .add_xaxis([a.isoformat(sep=' ') for a in port_record_set['Basis'].index.to_list()])
        .add_yaxis(
                    series_name="基差",
                    y_axis=round(port_record_set['Basis'].Value/1000).values.tolist()-port_record_set['Basis'].Value[0]/1000,
                    is_symbol_show = False,
                    label_opts=opts.LabelOpts(is_show=False),
                    linestyle_opts=opts.LineStyleOpts(width =1)
                    )
        .add_yaxis(
                    series_name="绝对值_DailyO",
                    y_axis=round(port_record_set['DailyOpen'].Value/1000).values.tolist()-port_record_set['DailyOpen'].Value[0]/1000,
                    is_symbol_show = False,
                    label_opts=opts.LabelOpts(is_show=False),
                    linestyle_opts=opts.LineStyleOpts(width = 1)
                    
                    )

        .add_yaxis(
                    series_name="绝对值_Roll",
                    y_axis=round(port_record_set['Roll'].Value/1000).values.tolist()-port_record_set['Roll'].Value[0]/1000,
                    is_symbol_show = False,
                    label_opts=opts.LabelOpts(is_show=False),
                    linestyle_opts=opts.LineStyleOpts(width = 1)
        )
        # .add_yaxis(
        #             series_name="绝对值_RollN",
        #             y_axis=round(port_record_set['RollN'].Value/1000).values.tolist()-port_record_set['RollN'].Value[0]/1000,
        #             is_symbol_show = False,
        #             label_opts=opts.LabelOpts(is_show=False),
        #             linestyle_opts=opts.LineStyleOpts(width = 1)
        # # )
        .extend_axis(
                    yaxis=opts.AxisOpts(
                                name = 'CN Pos',
                                max_ = 'dataMax',
                                min_ = 'dataMin',
                                splitline_opts=opts.SplitLineOpts(  is_show=False,
                                                                    linestyle_opts=opts.LineStyleOpts(opacity = 0.5),)
                            ),
                    )
        
        .set_global_opts(
                            legend_opts = opts.LegendOpts(pos_top = '1%',pos_left = '43%'),
                            title_opts = opts.TitleOpts('3IF-IC-27CN',),
                            xaxis_opts=opts.AxisOpts(
                                axislabel_opts=opts.LabelOpts(is_show = True),
                            ),
                            yaxis_opts=opts.AxisOpts(
                                name = 'Value',
                                max_ = 'dataMax',
                                min_ = 'dataMin',
                                axislabel_opts=opts.LabelOpts(formatter="{value} K"),
                                splitline_opts=opts.SplitLineOpts(  is_show=True,
                                                                    linestyle_opts=opts.LineStyleOpts(opacity = 0.5),)
                            ),
                            datazoom_opts=[
                                opts.DataZoomOpts(
                                    is_show=True, type_="inside", xaxis_index=[0, 0],#filter_mode = 'weakFilter',
                                ),
                                opts.DataZoomOpts(
                                    is_show=True, type_="slider",xaxis_index=[0, 0], pos_top="93%",#filter_mode = 'weakFilter',
                                ),
                                # opts.DataZoomOpts(
                                #     is_show=True, type_="slider",orient= "vertical",yaxis_index=[0, 0,1],range_start= -10,range_end=110
                                # ),
                            ],
                             tooltip_opts=opts.TooltipOpts(
                                trigger="axis",
                                axis_pointer_type="cross",
                                background_color="rgba(245, 245, 245, 0.8)",
                                border_width=1,
                                border_color="#ccc",
                                textstyle_opts=opts.TextStyleOpts(color="#000"),
                            ),
                            axispointer_opts=opts.AxisPointerOpts(
                                is_show=True, link=[{"xAxisIndex": [0]},{"yAxisIndex": [0]},]
                            ),
                        )
    )
totalCashUsage = (
    Bar()
    .add_xaxis([a.isoformat(sep=' ') for a in port_record.index.to_list()])
    .add_yaxis(
                series_name="基差",
                y_axis=port_record_set['Basis'].CN_pos.values.tolist(),
                yaxis_index = 1,
                label_opts=opts.LabelOpts(is_show=False),
                itemstyle_opts = opts.ItemStyleOpts(opacity=0.05, )
    )
    .add_yaxis(
                series_name="绝对值_Roll",
                y_axis=port_record_set['Roll'].CN_pos.values.tolist(),
                yaxis_index = 1,
                label_opts=opts.LabelOpts(is_show=False),
                itemstyle_opts = opts.ItemStyleOpts(opacity=0.05, )
    )
    .add_yaxis(
                series_name="绝对值_DailyO",
                y_axis=port_record_set['DailyOpen'].CN_pos.values.tolist(),
                yaxis_index = 1,
                label_opts=opts.LabelOpts(is_show=False),
                itemstyle_opts = opts.ItemStyleOpts(opacity=0.05, )
    )

   
    .set_global_opts(
                            legend_opts = opts.LegendOpts(pos_top = '1%',pos_left = '43%'),
                            xaxis_opts=opts.AxisOpts(
                                axislabel_opts=opts.LabelOpts(is_show = True),
                            ),
                            yaxis_opts=opts.AxisOpts(
                                name = 'position',
                                # max_ = 200,
                                # min_ = 0,
                                axislabel_opts=opts.LabelOpts(formatter="{value} K"),
                                splitline_opts=opts.SplitLineOpts(  is_show=True,
                                                                    linestyle_opts=opts.LineStyleOpts(opacity = 0.5),)
                            ),

    )
)

totalPortValue.overlap(totalCashUsage)
totalPortValue.render('3ific.html')
# Out:
# 'c:\\Users\\Alienware\\Desktop\\ah\\股指\\3ific.html'

# %%
class Trade(object): 
	def __init__(self, time, symbol, dir, price, size, comm): 
		self.time = time 
		self.symbol = symbol
		self.dir = dir 
		self.price = price 
		self.size = size
		self.comm = comm
	def __str__(self):
		return "{}, {}, {}, {}, {}, {}".format(self.time, self.symbol, self.dir, self.size, self.price,self.comm)
class ClosedTrade(object):
	def __init__(self,open_trade,close_trade):
		self.open_time = open_trade.time
		self.close_time = close_trade.time
		self.symbol = close_trade.size
		self.size = close_trade.size
		self.pnl = pnl
		self.open_side = open_trade.dir
		self.close_side = close_trade.dir
		self.open_price = open_trade.price
		self.close_price = close_trade.price

	# For printing out the closed trades
	def __str__(self):
		return "{},{},{},{},{},{},{},{},{}".format(self.open_time, self.close_time, self.symbol, self.quantity, self.pnl, self.open_side, self.close_side, self.open_price, self.close_price)

# %%
class p_2IFICCN(object): 
	def __init__(self,log_if,log_ic,log_cn,ref,margin): 
		self.time = log_if.Datetime 
		self.value = log_cn.Price * 15 * 6.5 - log_if.Price * 2 * 300 + log_ic.Price * 200 * 1
		self.comm = log_ic.Comm+log_cn.Comm+log_if.Comm
		self.dir = log_cn.Trade
		self.ref = ref
		self.basis_profit = 15*margin*6.5
	def __str__(self):
		return "{}, {}, {}, {}, {}".format(self.time, self.dir, self.value,self.comm,self.ref)

class p_3IFICCN(object): 
	def __init__(self,log_if,log_ic,log_cn,ref,margin): 
		self.time = log_if.Datetime 
		self.value = log_cn.Price * 30 * 6.5 - log_if.Price * 3 * 300 + log_ic.Price * 200 * 1
		self.comm = log_ic.Comm+log_cn.Comm+log_if.Comm
		self.dir = log_cn.Trade
		self.ref = ref
		self.basis_profit = 30*margin*6.5

	def __str__(self):
		return "{}, {}, {}, {}, {}".format(self.time, self.dir, self.value,self.comm,self.ref)

class ClosedPair(object):
	def __init__(self,open,close):
		self.open_time = open.time
		self.close_time = close.time
		self.comm = open.comm+close.comm
		self.pnl = ((close.value - open.value) if open.dir == 'Buy' else -(close.value - open.value)) - self.comm
		self.basis_profit = close.basis_profit
		self.dir = open.dir
		self.open_ref = open.ref
		self.clsoe_ref = close.ref
	def __str__(self):
		return "{}, {}, {}, {}".format(self.open_time, self.close_time, self.dir,self.pnl)

# %%
trade_list = []
for idx,row in trade_log.iterrows():
	trade_list.append(Trade(idx,row.Symbol,row.Trade,row.Price,row.Size,row.Comm))
temp_trade_log = trade_log.reset_index()

abs_trade_list = []
for idx,row in abs_trade_log.iterrows():
	abs_trade_list.append(Trade(idx,row.Symbol,row.Trade,row.Price,row.Size,row.Comm))
abs_temp_trade_log = abs_trade_log.reset_index()

# %%
pair_list = []
count = 0
for i in range(0,len(temp_trade_log)//3):
	if_row = temp_trade_log.iloc[3*i]
	ic_row = temp_trade_log.iloc[3*i+1]
	cn_row = temp_trade_log.iloc[3*i+2]
	n = ic_row.Size
	for d in range(0,abs(n)):
		pair_list.append(p_3IFICCN(if_row,ic_row,cn_row,count,35))
		count = count + 1

abs_pair_list = []
count = 0
for i in range(0,len(abs_temp_trade_log)//3):
	if_row = abs_temp_trade_log.iloc[3*i]
	ic_row = abs_temp_trade_log.iloc[3*i+1]
	cn_row = abs_temp_trade_log.iloc[3*i+2]
	n = ic_row.Size
	for d in range(0,abs(n)):
		abs_pair_list.append(p_3IFICCN(if_row,ic_row,cn_row,count,35))
		count = count + 1

# %%
closed_list = []
position_stack = deque()
port_record['Win'] = np.nan
port_record['Lose'] = np.nan

for item in pair_list:
    if len(position_stack) == 0 or item.dir == position_stack[-1].dir:
        position_stack.append(item)
    else:
        closedItem = ClosedPair(position_stack.pop(),item)
        closed_list.append(closedItem)
        if closedItem.pnl > 0:
            port_record.loc[closedItem.close_time,'Win'] = closedItem.pnl
        else:
            port_record.loc[closedItem.close_time,'Lose'] = closedItem.pnl

# %%
abs_closed_list = []
abs_position_stack = deque()
abs_port_record['PnL'] = np.nan
for item in abs_pair_list:
    if len(abs_position_stack) == 0 or item.dir == abs_position_stack[-1].dir:
        abs_position_stack.append(item)
    else:
        closedItem = ClosedPair(abs_position_stack.pop(),item)
        abs_closed_list.append(closedItem)
        if closedItem.pnl > 0:
            abs_port_record.loc[closedItem.close_time,'Win'] = closedItem.pnl
        else:
            abs_port_record.loc[closedItem.close_time,'Lose'] = closedItem.pnl

# %%
def tradeMark(trade_date,trade_dir,trade_price):
    if trade_dir == 'Sell':
        return opts.MarkPointItem(  coord=[trade_date.date(),trade_price],
                                    symbol = 'circle',
                                    symbol_size = 10,
                                    itemstyle_opts = opts.ItemStyleOpts(color = 'green') )
    if trade_dir == 'Buy':
        return opts.MarkPointItem(  coord=[trade_date.date(),trade_price],
                                    symbol = 'circle',
                                    symbol_size = 10,
                                    itemstyle_opts = opts.ItemStyleOpts(color = 'red') )

# %% [markdown]
# ### Integrating into Grid
